# %% [markdown]
# * CrossmediaproductID - их кодирование через айдишники (единый для всей компании, по идее во всех проектах одинаковые)
# * Name - собственно само название МП
# * Cnt - число контактов с продуктом
# * Dur - длительность контакта

# %%
import pandas as pd

df_activity = pd.read_csv('activity_2022-09-01-2022-09-30.csv')

df_activity
# Out:
#                    SubjectID  CrossMediaProductID                        Name  \
# 0         441361688982366592                24021         Вконтакте TOTAL WEB
# 1         441361688982366592                20141            Fandom TOTAL WEB
# 2         441361688982366592                20169         Speedtest TOTAL WEB
# 3        1008813765626963972                10913          Whatsapp TOTAL WEB
# 4        1008813765626963972                23679                OK TOTAL WEB
# ...                      ...                  ...                         ...
# 1653807  6701361217345428299                10543   Youtube Subscriptions WEB
# 1653808  6701361217345428299                24382      Store Steampowered WEB
# 1653809  9007204939872883401                10798  Google Документы OTHER WEB
# 1653810  9007204939872883401                22241    Google Главная TOTAL WEB
# 1653811  9007204939872883401                10576       Google Mail TOTAL WEB
#
#          cnt  dur          dt
# 0          9   61  2022-09-01
# 1          7   76  2022-09-01
# 2          2   21  2022-09-01
# 3          3   41  2022-09-01
# 4          3   40  2022-09-01
# ...      ...  ...         ...
# 1653807    1   13  2022-09-30
# 1653808    7   57  2022-09-30
# 1653809    2   18  2022-09-30
# 1653810    1    1  2022-09-30
# 1653811    4   50  2022-09-30
#
# [1653812 rows x 6 columns]

# %%
print("Mean:", df_activity['dur'].mean())
print("Variance:", df_activity['dur'].var())
# Out:
# Mean: 525.7552732716899
# Variance: 11112495.554589529

# %%
correlation = df_activity['cnt'].corr(df_activity['dur'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.2356298641832516

# %%
import seaborn as sns

correlation_matrix = df_activity[['cnt', 'dur']].corr()
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
df_resp = pd.read_csv('resps_2022-09-01-2022-09-30.csv')

df_resp
# Out:
#                   SubjectID  Population Возрастные группы    Занятость  \
# 0       1585271561336594419        78.0             45-54  не работает
# 1       1585271561336732121        23.0             35-44     работает
# 2       1585271561336928001        99.0               65+  не работает
# 3       1585271561336962113        14.0             45-54     работает
# 4       1585271561337052322       208.0             25-34     работает
# ...                     ...         ...               ...          ...
# 403437  2738194092690288974        69.0             25-34     работает
# 403438  6341074104264856315        71.0             25-34     работает
# 403439  1585271561336856731        33.0             45-54     работает
# 403440  1585271561336868182        26.0             45-54     работает
# 403441  6629304165209876291        26.0             45-54     работает
#
#        Количество человек в семье Образование      Пол  \
# 0              3 человека в семье      высшее  Женщины
# 1             4+ человека в семье      высшее  Женщины
# 2              2 человека в семье     среднее  Женщины
# 3              2 человека в семье      высшее  Женщины
# 4              3 человека в семье     среднее  Мужчины
# ...                           ...         ...      ...
# 403437         3 человека в семье     среднее  Мужчины
# 403438         3 человека в семье     среднее  Мужчины
# 403439         3 человека в семье      высшее  Мужчины
# 403440         3 человека в семье      высшее  Мужчины
# 403441         3 человека в семье      высшее  Мужчины
#
#                                        Семейное положение  \
# 0                        женат/ замужем/ гражданский брак
# 1                        женат/ замужем/ гражданский брак
# 2                        женат/ замужем/ гражданский брак
# 3       холост/ незамужем/ разведен(а)/вдовец (вдова)/...
# 4       холост/ незамужем/ разведен(а)/вдовец (вдова)/...
# ...                                                   ...
# 403437  холост/ незамужем/ разведен(а)/вдовец (вдова)/...
# 403438                   женат/ замужем/ гражданский брак
# 403439                   женат/ замужем/ гражданский брак
# 403440                   женат/ замужем/ гражданский брак
# 403441                   женат/ замужем/ гражданский брак
#
#                                            Уровень дохода  \
# 0                         Хватает на еду, но не на одежду
# 1                                    затрудняюсь ответить
# 2                         Хватает на еду, но не на одежду
# 3       Хватает на дорогие вещи, но не на все что захотим
# 4       Хватает на дорогие вещи, но не на все что захотим
# ...                                                   ...
# 403437                    Хватает на еду, но не на одежду
# 403438     Хватает на еду и одежду, но не на дорогие вещи
# 403439     Хватает на еду и одежду, но не на дорогие вещи
# 403440     Хватает на еду и одежду, но не на дорогие вещи
# 403441     Хватает на еду и одежду, но не на дорогие вещи
#
#        Федеральный округ (БМ и СПб отдельно) Численность населенного пункта  \
# 0        Центральный ФО (без Большой Москвы)                   Россия 100К-
# 1        Центральный ФО (без Большой Москвы)               Города 100К-400К
# 2        Центральный ФО (без Большой Москвы)               Города 100К-400К
# 3        Центральный ФО (без Большой Москвы)               Города 100К-400К
# 4        Центральный ФО (без Большой Москвы)                   Россия 100К-
# ...                                      ...                            ...
# 403437                          Сибирский ФО               Города 100К-400К
# 403438                        Приволжский ФО               Города 100К-400К
# 403439                        Приволжский ФО               Города 100К-400К
# 403440                        Большая Москва                 Большая Москва
# 403441                        Большая Москва                 Большая Москва
#
#                 dt
# 0       2022-09-01
# 1       2022-09-01
# 2       2022-09-01
# 3       2022-09-01
# 4       2022-09-01
# ...            ...
# 403437  2022-09-30
# 403438  2022-09-30
# 403439  2022-09-30
# 403440  2022-09-30
# 403441  2022-09-30
#
# [403442 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
df_resp['Возрастные группы'].value_counts().plot(kind='bar', color = 'blue')

for i, v in enumerate(df_resp['Возрастные группы'].value_counts()):
    plt.text(i, v + 3, str(v), ha='center')

plt.xlabel('Значение')
plt.ylabel('Количество')
plt.title('Гистограмма количества значений колонки')

plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

age_counts = df_resp['Возрастные группы'].value_counts()

desired_order = ['12-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+']
age_counts = age_counts.reindex(desired_order)

age_counts.plot(kind='bar', color='blue')

for i, v in enumerate(age_counts):
    plt.text(i, v + 3, str(v), ha='center')

plt.xlabel('Возраст')
plt.ylabel('Количество людей')
plt.title('График количества людей по возрасту')

plt.xticks(rotation=0)

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

columns_to_encode = ['Возрастные группы', 'Занятость', 'Количество человек в семье', 
                     'Образование', 'Пол', 'Семейное положение', 'Уровень дохода',
                     'Федеральный округ (БМ и СПб отдельно)', 'Численность населенного пункта']

for column in columns_to_encode:
    df_resp[column] = le.fit_transform(df_resp[column]) + 1
    
df_resp
# Out:
#                   SubjectID  Population  Возрастные группы  Занятость  \
# 0       1585271561336594419        78.0                  5          1
# 1       1585271561336732121        23.0                  4          2
# 2       1585271561336928001        99.0                  7          1
# 3       1585271561336962113        14.0                  5          2
# 4       1585271561337052322       208.0                  3          2
# ...                     ...         ...                ...        ...
# 403437  2738194092690288974        69.0                  3          2
# 403438  6341074104264856315        71.0                  3          2
# 403439  1585271561336856731        33.0                  5          2
# 403440  1585271561336868182        26.0                  5          2
# 403441  6629304165209876291        26.0                  5          2
#
#         Количество человек в семье  Образование  Пол  Семейное положение  \
# 0                                3            1    1                   1
# 1                                4            1    1                   1
# 2                                2            3    1                   1
# 3                                2            1    1                   2
# 4                                3            3    2                   2
# ...                            ...          ...  ...                 ...
# 403437                           3            3    2                   2
# 403438                           3            3    2                   1
# 403439                           3            1    2                   1
# 403440                           3            1    2                   1
# 403441                           3            1    2                   1
#
#         Уровень дохода  Федеральный округ (БМ и СПб отдельно)  \
# 0                    5                                      8
# 1                    6                                      8
# 2                    5                                      8
# 3                    3                                      8
# 4                    3                                      8
# ...                ...                                    ...
# 403437               5                                      6
# 403438               4                                      3
# 403439               4                                      3
# 403440               4                                      1
# 403441               4                                      1
#
#         Численность населенного пункта          dt
# 0                                    5  2022-09-01
# 1                                    2  2022-09-01
# 2                                    2  2022-09-01
# 3                                    2  2022-09-01
# 4                                    5  2022-09-01
# ...                                ...         ...
# 403437                               2  2022-09-30
# 403438                               2  2022-09-30
# 403439                               2  2022-09-30
# 403440                               1  2022-09-30
# 403441                               1  2022-09-30
#
# [403442 rows x 12 columns]

# %%
columns_to_drop = ['SubjectID', 'Population', 'dt']
df_resp = df_resp.drop(columns=columns_to_drop)

df_resp
# Out:
#         Возрастные группы  Занятость  Количество человек в семье  Образование  \
# 0                       5          1                           3            1
# 1                       4          2                           4            1
# 2                       7          1                           2            3
# 3                       5          2                           2            1
# 4                       3          2                           3            3
# ...                   ...        ...                         ...          ...
# 403437                  3          2                           3            3
# 403438                  3          2                           3            3
# 403439                  5          2                           3            1
# 403440                  5          2                           3            1
# 403441                  5          2                           3            1
#
#         Пол  Семейное положение  Уровень дохода  \
# 0         1                   1               5
# 1         1                   1               6
# 2         1                   1               5
# 3         1                   2               3
# 4         2                   2               3
# ...     ...                 ...             ...
# 403437    2                   2               5
# 403438    2                   1               4
# 403439    2                   1               4
# 403440    2                   1               4
# 403441    2                   1               4
#
#         Федеральный округ (БМ и СПб отдельно)  Численность населенного пункта
# 0                                           8                               5
# 1                                           8                               2
# 2                                           8                               2
# 3                                           8                               2
# 4                                           8                               5
# ...                                       ...                             ...
# 403437                                      6                               2
# 403438                                      3                               2
# 403439                                      3                               2
# 403440                                      1                               1
# 403441                                      1                               1
#
# [403442 rows x 9 columns]

# %%
from sklearn.linear_model import LogisticRegression

df_ml = df_resp

# Определяем признаки (X) и целевую переменную (y)
X = df_ml.drop(columns=['Занятость'])
y = df_ml['Занятость']

# Создаем и обучаем модель логистической регрессии
model = LogisticRegression()
model.fit(X, y)

predicted_values = model.predict(X)

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y, predicted_values)
print("Точность оценки параметра y:", accuracy)
# Out:
# Точность оценки параметра y: 0.7271305416887681

# %%
correlation_matrix = df_resp.corr()
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
from scipy.stats import binom
from scipy.optimize import minimize

# Генерим выборку из биномиального распределения
n = 1000  # количество испытаний
p = 0.5  # вероятность успеха
sample = np.random.binomial(n, p, size=100)

# Определяем функцию правдоподобия
def likelihood(params):
    p = params[0]
    return -np.sum(binom.logpmf(sample, n, p))

# Поиск параметра, максимизирующего функцию правдоподобия
result = minimize(likelihood, [0.5], method='Nelder-Mead')
estimated_p = result.x[0]

print("Оценка параметра p:", estimated_p)
# Out:
# Оценка параметра p: 0.4989013671875

# %%
from scipy.stats import binom

n = 10  # количество испытаний
p = 0.5  # вероятность успеха в каждом испытании

x = 5  # число успехов
log_pmf = binom.logpmf(x, n, p)
print(log_pmf)
# Out:
# -1.4020427180880288

# %%
import numpy as np
from scipy.optimize import minimize

sample = df_activity['dur']

# Определение функции правдоподобия
def likelihood(params):
    mu, sigma = params
    log_likelihood = -np.sum(np.log(sigma) + 0.5*np.log(2*np.pi) + ((sample - mu)**2) / (2*sigma**2))
    return -log_likelihood

# Начальные значения параметров
initial_params = [50,20]
# initial_params = [df_activity['dur'].mean(), df_activity['dur'].var()]

# Минимизация отрицательного логарифма функции правдоподобия
result = minimize(likelihood, initial_params)

# Оценки параметров методом максимального правдоподобия
mu_mle, sigma_mle = result.x

print(f"Реальное среднее: {df_activity['dur'].mean()}")
print(f"Реальная дисперсия: {df_activity['dur'].var()}")

print(f"Оценка среднего значения: {mu_mle}")
print(f"Оценка дисперсии: {sigma_mle}")
# Out:
# Реальное среднее: 525.7552732716899
# Реальная дисперсия: 11112495.554589529
# Оценка среднего значения: 525.2333802116104
# Оценка дисперсии: 3331.5604821325
